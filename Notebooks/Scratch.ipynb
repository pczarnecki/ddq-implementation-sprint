# %%
import xarray as xr

# %%
xr.open_dataset('/home/pczarnec/.cache/pyrte_rrtmgp')

# %%
xr.open_dataset('/homedata/pczarnec/ddq-data/gas_optics_lw.nc')
# Out:
# <xarray.Dataset> Size: 46kB
# Dimensions:              (nu: 64, fax_nspecies: 7, fax_p_nterms: 4,
#                           fax_t_order: 3, xsec_nspecies: 2, xsec_nterms: 4,
#                           mtckd_nspecies: 1)
# Coordinates:
#   * nu                   (nu) float32 256B 127.9 146.5 ... 2.111e+03 3.073e+03
#   * fax_nspecies         (fax_nspecies) int64 56B 0 1 2 3 4 5 6
#   * fax_p_nterms         (fax_p_nterms) int64 32B 0 1 2 3
#   * fax_t_order          (fax_t_order) int64 24B 0 1 2
#   * xsec_nspecies        (xsec_nspecies) int64 16B 0 1
#   * xsec_nterms          (xsec_nterms) int64 32B 0 1 2 3
#   * mtckd_nspecies       (mtckd_nspecies) int64 8B 0
# Data variables: (12/17)
#     weights              (nu) float64 512B ...
#     fax_species_names    (fax_nspecies) |S32 224B ...
#     fax_p0               (fax_nspecies) float64 56B ...
#     fax_T0               (fax_nspecies) float64 56B ...
#     fax_S                (fax_nspecies) float64 56B ...
# ...
